# %%
# !pip install pymysql
# !pip install apyori
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn 
# !pip install python-dotenv
# Out:
# Requirement already satisfied: pymysql in c:\users\ihand\appdata\local\programs\python\python39\lib\site-packages (1.0.2)
# Requirement already satisfied: apyori in c:\users\ihand\appdata\local\programs\python\python39\lib\site-packages (1.1.2)
# Requirement already satisfied: pandas in c:\users\ihand\appdata\local\programs\python\python39\lib\site-packages (1.2.4)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\ihand\appdata\local\programs\python\python39\lib\site-packages (from pandas) (1.20.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\ihand\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\ihand\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\users\ihand\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Requirement already satisfied: matplotlib in c:\users\ihand\appdata\local\programs\python\python39\lib\site-packages (3.4.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\ihand\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (8.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\ihand\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\ihand\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: numpy>=1.16 in c:\users\ihand\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (1.20.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ihand\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ihand\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (2.8.1)
# Requirement already satisfied: six in c:\users\ihand\appdata\local\programs\python\python39\lib\site-packages (from cycler>=0.10->matplotlib) (1.15.0)
# Requirement already satisfied: seaborn in c:\users\ihand\appdata\local\programs\python\python39\lib\site-packages (0.11.1)
# Requirement already satisfied: numpy>=1.15 in c:\users\ihand\appdata\local\programs\python\python39\lib\site-packages (from seaborn) (1.20.2)
# Requirement already satisfied: scipy>=1.0 in c:\users\ihand\appdata\local\programs\python\python39\lib\site-packages (from seaborn) (1.6.3)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\ihand\appdata\local\programs\python\python39\lib\site-packages (from seaborn) (3.4.1)
# Requirement already satisfied: pandas>=0.23 in c:\users\ihand\appdata\local\programs\python\python39\lib\site-packages (from seaborn) (1.2.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ihand\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\ihand\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=2.2->seaborn) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\ihand\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=2.2->seaborn) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ihand\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=2.2->seaborn) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\ihand\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=2.2->seaborn) (8.2.0)
# Requirement already satisfied: six in c:\users\ihand\appdata\local\programs\python\python39\lib\site-packages (from cycler>=0.10->matplotlib>=2.2->seaborn) (1.15.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\ihand\appdata\local\programs\python\python39\lib\site-packages (from pandas>=0.23->seaborn) (2021.1)
# Requirement already satisfied: python-dotenv in c:\users\ihand\appdata\local\programs\python\python39\lib\site-packages (0.17.1)

# %%
# Imported Libraries
import pandas as pd
import pymysql

import os

# Data visualisation tools for later.
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from apyori import apriori


# Load the .env file for database credentials
from dotenv import load_dotenv

load_dotenv()

####### Connection to Client Database #######
conn = pymysql.connect(host=os.getenv("host"), user=os.getenv("user"), port=int(os.getenv("port")), password=os.getenv("password"), db=os.getenv("dbname"))

print(conn)

# print(conn)
# Out:
# <pymysql.connections.Connection object at 0x0000017932ABED90>

# %% [markdown]
# ### Getting Customer-users detail - make dataframe

# %%
####Checking queries

###Customer Personal details
##  add the desired rows in the query from the three tables
#df_snow_cus = pd.read_sql("select m.id as member_id, m.membership_number, m.status, m.price_zone_code, s.u_ndis_number, s.u_disabilities, s.u_gender, s.u_date_of_birth, r.SA1, r.SA2, r.SA3,r.SA4  from SNOW_csm_consumer_user s left join  HH_member m  on s.u_ndis_number = m.membership_number left join libe_leapinprod_memberregion r on r.MemberId =  s.u_leapin_id where s.u_stage = 'li_managed' and s.u_ndis_number is not null;", con=conn)
#print(df_snow_cus.info())
#print(df_snow_cus)
df_customer_details = pd.read_sql("select m.id as member_id, m.membership_number, m.status, m.price_zone_code, s.u_ndis_number, s.u_disabilities, s.u_gender, s.u_date_of_birth, r.SA1, r.SA2, r.SA3,r.SA4  from SNOW_csm_consumer_user s left join  HH_member m  on s.u_ndis_number = m.membership_number left join libe_leapinprod_memberregion r on r.MemberId =  s.u_leapin_id where s.u_stage = 'li_managed' and s.u_ndis_number is not null;", con=conn)
print(df_customer_details.info())
print(df_customer_details)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6241 entries, 0 to 6240
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   member_id          6115 non-null   float64
#  1   membership_number  6115 non-null   object
#  2   status             6115 non-null   object
#  3   price_zone_code    6115 non-null   object
#  4   u_ndis_number      6241 non-null   object
#  5   u_disabilities     6241 non-null   object
#  6   u_gender           6241 non-null   object
#  7   u_date_of_birth    6239 non-null   object
#  8   SA1                6021 non-null   float64
#  9   SA2                6021 non-null   float64
#  10  SA3                6021 non-null   float64
#  11  SA4                6021 non-null   float64
# dtypes: float64(5), object(7)
# memory usage: 585.2+ KB
# None
#       member_id membership_number   status  price_zone_code u_ndis_number  \
# 0        1613.0         916644409  managed  ACT_NSW_QLD_VIC     916644409
# 1        3132.0         262354568  managed  ACT_NSW_QLD_VIC     262354568
# 2        1786.0         233367363  managed  ACT_NSW_QLD_VIC     233367363
# 3        2562.0         981297214  managed  ACT_NSW_QLD_VIC     981297214
# 4        1614.0         631304335  managed  ACT_NSW_QLD_VIC     631304335
# ...         ...               ...      ...              ...           ...
# 6236        NaN              None     None             None     703118745
# 6237        NaN              None     None             None     733148654
# 6238        NaN              None     None             None      78970714
# 6239        NaN              None     None             None     828365433
# 6240        NaN              None     None             None     947518653
#
#             u_disabilities u_gender u_date_of_birth        SA1      SA2  \
# 0                                        1922-11-30  3100614.0  31006.0
# 1                                        2007-04-06  1144614.0  11446.0
# 2                            Female      1954-03-26        0.0      0.0
# 3                            Female      1978-12-24  3138504.0  31385.0
# 4                                        1995-08-18  2142119.0  21421.0
# ...                    ...      ...             ...        ...      ...
# 6236                         Female      1951-09-13        0.0      0.0
# 6237                         Female      1953-09-24        0.0      0.0
# 6238                         Female      1989-01-29  3131715.0  31317.0
# 6239                         Female      1938-10-29        0.0      0.0
# 6240  Permanent blindness,               2000-12-10        NaN      NaN
#
#           SA3    SA4
# 0     30101.0  301.0
# 1     12303.0  123.0
# 2         0.0    0.0
# 3     31401.0  314.0
# 4     21701.0  217.0
# ...       ...    ...
# 6236      0.0    0.0
# 6237      0.0    0.0
# 6238  31103.0  311.0
# 6239      0.0    0.0
# 6240      NaN    NaN
#
# [6241 rows x 12 columns]

# %% [markdown]
# ### Getting Services Providers detail - make dataframe

# %%
####Checking queries
### Service Providers Details:

#df_providers_details = pd.read_sql("select p.id, pa.provider_account_key, p.is_inactive, p.abn, ca.city, ca.country from HH_provider_account pa join HH_provider p on p.id = pa.provider_id join SNOW_customer_account ca on ca.u_abn = p.abn;", con=conn)

#print(df_providers_details.info())

#df_providers_details.head(50)

# %% [markdown]
# ### Getting Claims and Invoice details - make dataframe

# %%
### Checking Queries:
### Getting Claims-Providers details:

##df_invoice_claim_details = pd.read_sql("SELECT c.id as claim_id, c.invoice_id, c.state, c.risk_score, c.risk_level, c.risk_warnings, c.unit_price, c.start_date, c.end_date, c.invoiced_units, c.invoiced_unit_price, c.claimed_units, c.claimed_unit_price, c.claimed_date, c.funded_amount, c.funded_date, c.submitted_date, c.approved_date, c.received_date, c.processed_status, c.reconcile_status, c.ndis_cancelled_date, c.cancel_offset_z4_no, i.state, i.is_pre_approved, i.is_resolved, i.is_risk_identified, i.risk_score, i.invoice_total, i.funded_total, i.funded_date, i.claimed_date, i.reviewed_date, i.invoice_date, i.approved_date, i.submitted_date, i.received_date, m.membership_number, m.status, m.risk_factor, m.price_zone_code FROM HH_claim c left join HH_invoice i on c.invoice_id = i.id left join HH_member m on i.member_id = m.id ;", con=conn)

##df_invoice_claim_details.info()
##df_invoice_claim_details

# %%
### Getting Claims details: 

df_claims= pd.read_sql("SELECT c.id as claim_id, c.invoice_id, c.state, c.risk_level, c.start_date FROM HH_claim c;", con=conn)
##df_claims.info()
#df_claims

###Getting Invoice Details

df_invoices= pd.read_sql("SELECT i.id as invoice_id, i.member_id, i.invoice_total, i.funded_total, i.funded_date FROM HH_invoice i;", con=conn)
#df_invoices.info()
#df_invoices

###Getting Member Details

#df_mem= pd.read_sql("SELECT m.id as member_id, m.membership_number, m.status, m.price_zone_code FROM HH_member m;", con=conn)
#df_mem.info()
#df_mem

### Merging
df_claimsWithInvoices = pd.merge(df_claims, df_invoices, on="invoice_id", how="left")
#df_invoice_claim_details = pd.merge(df_claimsWithInvoices, df_mem, on="member_id", how="left")

#df_claimsWithInvoices.info()
df_invoice_claim_details= df_claimsWithInvoices
df_invoice_claim_details.info()
df_invoice_claim_details
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 968874 entries, 0 to 968873
# Data columns (total 9 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   claim_id       968874 non-null  int64
#  1   invoice_id     968874 non-null  int64
#  2   state          968874 non-null  object
#  3   risk_level     968874 non-null  object
#  4   start_date     968874 non-null  object
#  5   member_id      968874 non-null  int64
#  6   invoice_total  968874 non-null  float64
#  7   funded_total   566458 non-null  float64
#  8   funded_date    556790 non-null  object
# dtypes: float64(2), int64(3), object(4)
# memory usage: 73.9+ MB
#         claim_id  invoice_id                state risk_level  start_date  \
# 0              1           1                 PAID         NO  2020-04-30
# 1              2           2                 PAID         NO  2020-05-01
# 2              3           3                 PAID         NO  2020-04-23
# 3              4           4                 PAID         NO  2020-04-30
# 4              5           5                 PAID         NO  2020-05-07
# ...          ...         ...                  ...        ...         ...
# 968869   1006095      539315  OPERATOR_AUTHORIZED         NO  2021-04-08
# 968870   1006096      539315  OPERATOR_AUTHORIZED         NO  2021-04-10
# 968871   1006097      539315  OPERATOR_AUTHORIZED         NO  2021-04-11
# 968872   1006098      539316  OPERATOR_AUTHORIZED         NO  2021-04-15
# 968873   1006099      539316  OPERATOR_AUTHORIZED         NO  2021-04-15
#
#         member_id  invoice_total  funded_total funded_date
# 0               2         160.00         160.0  2020-04-30
# 1               2         160.00         160.0  2020-05-05
# 2               3          80.00          80.0  2020-05-08
# 3               3          80.00          80.0  2020-05-08
# 4               3          80.00          80.0  2020-05-08
# ...           ...            ...           ...         ...
# 968869       3000        2135.70           NaN        None
# 968870       3000        2135.70           NaN        None
# 968871       3000        2135.70           NaN        None
# 968872       3607         396.57           NaN        None
# 968873       3607         396.57           NaN        None
#
# [968874 rows x 9 columns]

# %%
df_invoice_claim = pd.merge(df_claims, df_invoices, on="invoice_id", how="left")

checked_df = df_invoice_claim.groupby(["member_id"]).agg({'invoice_total': 'sum', 'funded_total': 'sum'}).reset_index()
#df_invoice_claim['invoice_total'] = df_invoice_claim.groupby(['member_id'])['invoice_total'].transform('sum')
checked_df
# Out:
#       member_id  invoice_total  funded_total
# 0             2        6237.00       6237.00
# 1             3        1449.95       1449.95
# 2             4       15350.19      14582.20
# 3             5        6283.44       6283.45
# 4             6       44130.22      25497.63
# ...         ...            ...           ...
# 6130       6662         330.69        330.69
# 6131       6673        5045.00        245.00
# 6132       6677         193.99        193.99
# 6133       6679         502.00        502.00
# 6134       6691        9953.37       9953.37
#
# [6135 rows x 3 columns]

# %%
checked_df['subtraction'] = checked_df['invoice_total'] - checked_df['funded_total']
checked_df
# Out:
#       member_id  invoice_total  funded_total  subtraction
# 0             2        6237.00       6237.00         0.00
# 1             3        1449.95       1449.95         0.00
# 2             4       15350.19      14582.20       767.99
# 3             5        6283.44       6283.45        -0.01
# 4             6       44130.22      25497.63     18632.59
# ...         ...            ...           ...          ...
# 6130       6662         330.69        330.69         0.00
# 6131       6673        5045.00        245.00      4800.00
# 6132       6677         193.99        193.99         0.00
# 6133       6679         502.00        502.00         0.00
# 6134       6691        9953.37       9953.37         0.00
#
# [6135 rows x 4 columns]

# %%
checked_df['subtraction'].value_counts(sort=True).nlargest().plot.pie()
# Out:
# <AxesSubplot:ylabel='subtraction'>

# %%
sub_0 = checked_df[checked_df['subtraction']> 0]
sub_0
# Out:
#       member_id  invoice_total  funded_total  subtraction
# 2             4       15350.19      14582.20       767.99
# 4             6       44130.22      25497.63     18632.59
# 8            10         225.00          0.00       225.00
# 11           13       38838.02      38372.79       465.23
# 12           14       97878.90      97707.02       171.88
# ...         ...            ...           ...          ...
# 6099       6555       10518.09      10177.77       340.32
# 6102       6560       16972.43      15833.19      1139.24
# 6106       6574        1261.05       1051.05       210.00
# 6122       6613     1091785.54    1090196.52      1589.02
# 6131       6673        5045.00        245.00      4800.00
#
# [4458 rows x 4 columns]

# %%
not_full_funded = len(sub_0)/len(checked_df)*100
not_full_funded
# Out:
# 72.66503667481663

# %% [markdown]
# ### Checking Claims_id and Providers link - making dataframe

# %%
### All Claim details (took 2 minutes to execute)
##  
df_all_claims = pd.read_sql("select c.id as claim_id, invoice_id as invoiceId, c.item_category_level3_id from HH_claim c", con=conn)

#print(df_all_claims.info())
#print(df_all_claims)
### All item_categories details. Took few seconds for execution.

##  
df_all_ndis_service_cat = pd.read_sql("select item_category_level3_id, ndis.registration_group from hedgehog_ndis_service_item_ref ndis", con=conn)
#print(df_all_ndis_service_cat.info())
#print(df_all_ndis_service_cat)

##Combine df_all_claims and df_all_ndis_service_cat
df_claimsWithProvider_details = pd.merge(df_all_claims, df_all_ndis_service_cat, on="item_category_level3_id", how= 'inner')
df_claimsWithProvider_details= df_claimsWithProvider_details.drop(columns=['item_category_level3_id'])
#df_claimsWithProvider_details = pd.read_sql("select c.id, c.invoice_id as invoiceId, n.registration_group from HH_claim c left join hedgehog_ndis_service_item_ref n on c.item_category_level3_id = n.item_category_level3_id;", con=conn)
#print(df_claimsWithProvider_details.info())
#print(df_claimsWithProvider_details)

### Provider Services details (Provider account linked to invoice and HH_provider) took 1 minute to execute
##  
df_providersWithInvoice_details = pd.read_sql("select i.id as invoiceId, i.provider_account_id, (select p.abn from HH_provider p where pa.provider_id= p.id) as provider_abn from HH_invoice i left join HH_provider_account pa on i.provider_account_id = pa.id;", con=conn)
#print(df_providersWithInvoice_details.info())
#print(df_providersWithInvoice_details)

##Combine df_claim_providers_details and df_providersWithInvoice_details
df_claims_provider_details= pd.merge(df_claimsWithProvider_details, df_providersWithInvoice_details, on="invoiceId", how="left")

##################################################

#Final claim and Provider df
print(df_claims_provider_details.info())
print(df_claims_provider_details)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 969779 entries, 0 to 969778
# Data columns (total 5 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   claim_id             969779 non-null  int64
#  1   invoiceId            969779 non-null  int64
#  2   registration_group   969779 non-null  object
#  3   provider_account_id  969779 non-null  int64
#  4   provider_abn         940538 non-null  object
# dtypes: int64(3), object(2)
# memory usage: 44.4+ MB
# None
#         claim_id  invoiceId                               registration_group  \
# 0              1          1                             Therapeutic Supports
# 1              2          2                             Therapeutic Supports
# 2              3          3                             Therapeutic Supports
# 3              4          4                             Therapeutic Supports
# 4              5          5                             Therapeutic Supports
# ...          ...        ...                                              ...
# 969774    967635     520409                 Specialised Supported Employment
# 969775    980261     526511  Assistive Products For Personal Care And Safety
# 969776   1000228     536789  Assistive Products For Personal Care And Safety
# 969777   1003943     538305                Group And Centre Based Activities
# 969778   1005045     538715  Assistive Products For Personal Care And Safety
#
#         provider_account_id provider_abn
# 0                       157  13448919450
# 1                       157  13448919450
# 2                      1877    454964437
# 3                      1877    454964437
# 4                      1877    454964437
# ...                     ...          ...
# 969774                  860  27009942269
# 969775                16806         None
# 969776                 2806  62630886887
# 969777                11611  21170525763
# 969778                12827         None
#
# [969779 rows x 5 columns]

# %% [markdown]
# ## Merging the dataframes

# %%
#Merging invoice, claim and member
df_invoice_claim_cus = pd.merge(df_invoice_claim_details, df_customer_details, on="member_id", how="left")

#The membership_number is 902999 because we have considered the members only with 'li_managed' stage. 
#The records for members having the member id and not having the membership number needs to be dropped.
filter1 = df_invoice_claim_cus ["membership_number"].notnull()
df_invoice_claim_cus.where(filter1, inplace = True)
df_invoice_claim_cus.info()
df_invoice_claim_cus 
#Merging with service providers
df_final = pd.merge(df_invoice_claim_cus, df_claims_provider_details, on="claim_id", how="left")
df_final= df_final.drop(columns=['invoiceId'])
df_final.info()

#There are some claims which do not have a provider specific information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 968874 entries, 0 to 968873
# Data columns (total 20 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   claim_id           902999 non-null  float64
#  1   invoice_id         902999 non-null  float64
#  2   state              902999 non-null  object
#  3   risk_level         902999 non-null  object
#  4   start_date         902999 non-null  object
#  5   member_id          902999 non-null  float64
#  6   invoice_total      902999 non-null  float64
#  7   funded_total       539632 non-null  float64
#  8   funded_date        530680 non-null  object
#  9   membership_number  902999 non-null  object
#  10  status             902999 non-null  object
#  11  price_zone_code    902999 non-null  object
#  12  u_ndis_number      902999 non-null  object
#  13  u_disabilities     902999 non-null  object
#  14  u_gender           902999 non-null  object
#  15  u_date_of_birth    902946 non-null  object
#  16  SA1                885027 non-null  float64
#  17  SA2                885027 non-null  float64
#  18  SA3                885027 non-null  float64
#  19  SA4                885027 non-null  float64
# dtypes: float64(9), object(11)
# memory usage: 155.2+ MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 969735 entries, 0 to 969734
# Data columns (total 23 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   claim_id             903860 non-null  float64
#  1   invoice_id           903860 non-null  float64
#  2   state                903860 non-null  object
#  3   risk_level           903860 non-null  object
#  4   start_date           903860 non-null  object
#  5   member_id            903860 non-null  float64
#  6   invoice_total        903860 non-null  float64
#  7   funded_total         540423 non-null  float64
#  8   funded_date          531471 non-null  object
#  9   membership_number    903860 non-null  object
#  10  status               903860 non-null  object
#  11  price_zone_code      903860 non-null  object
#  12  u_ndis_number        903860 non-null  object
#  13  u_disabilities       903860 non-null  object
#  14  u_gender             903860 non-null  object
#  15  u_date_of_birth      903807 non-null  object
#  16  SA1                  885884 non-null  float64
#  17  SA2                  885884 non-null  float64
#  18  SA3                  885884 non-null  float64
#  19  SA4                  885884 non-null  float64
#  20  registration_group   903860 non-null  object
#  21  provider_account_id  903860 non-null  float64
#  22  provider_abn         876793 non-null  object
# dtypes: float64(10), object(13)
# memory usage: 177.6+ MB

# %%
df_invoice_claim = pd.merge(df_claims, df_invoices, on="invoice_id", how="left")

df_invoice_claim = df_invoice_claim.groupby(["member_id"])

df_invoice_claim.head(100)
# Out:
#         claim_id  invoice_id                state risk_level  start_date  \
# 0              1           1                 PAID         NO  2020-04-30
# 1              2           2                 PAID         NO  2020-05-01
# 2              3           3                 PAID         NO  2020-04-23
# 3              4           4                 PAID         NO  2020-04-30
# 4              5           5                 PAID         NO  2020-05-07
# ...          ...         ...                  ...        ...         ...
# 968861   1006087      539308  OPERATOR_AUTHORIZED         NO  2021-04-15
# 968862   1006088      539309  OPERATOR_AUTHORIZED         NO  2021-04-06
# 968863   1006089      539310  OPERATOR_AUTHORIZED         NO  2020-10-08
# 968864   1006090      539311  OPERATOR_AUTHORIZED         NO  2020-12-03
# 968865   1006091      539312  OPERATOR_AUTHORIZED         NO  2021-02-01
#
#         member_id  invoice_total  funded_total funded_date
# 0               2         160.00         160.0  2020-04-30
# 1               2         160.00         160.0  2020-05-05
# 2               3          80.00          80.0  2020-05-08
# 3               3          80.00          80.0  2020-05-08
# 4               3          80.00          80.0  2020-05-08
# ...           ...            ...           ...         ...
# 968861       5433         190.00           NaN        None
# 968862       5867         576.00           NaN        None
# 968863        558         256.70           NaN        None
# 968864        558         184.45           NaN        None
# 968865        558         119.00           NaN        None
#
# [386871 rows x 9 columns]

# %%
pd.set_option('display.max_columns', 50)
df = df_final
df
# Out:
#          claim_id  invoice_id                state risk_level  start_date  \
# 0             1.0         1.0                 PAID         NO  2020-04-30
# 1             2.0         2.0                 PAID         NO  2020-05-01
# 2             3.0         3.0                 PAID         NO  2020-04-23
# 3             4.0         4.0                 PAID         NO  2020-04-30
# 4             5.0         5.0                 PAID         NO  2020-05-07
# ...           ...         ...                  ...        ...         ...
# 969730  1006095.0    539315.0  OPERATOR_AUTHORIZED         NO  2021-04-08
# 969731  1006096.0    539315.0  OPERATOR_AUTHORIZED         NO  2021-04-10
# 969732  1006097.0    539315.0  OPERATOR_AUTHORIZED         NO  2021-04-11
# 969733  1006098.0    539316.0  OPERATOR_AUTHORIZED         NO  2021-04-15
# 969734  1006099.0    539316.0  OPERATOR_AUTHORIZED         NO  2021-04-15
#
#         member_id  invoice_total  funded_total funded_date membership_number  \
# 0             2.0         160.00         160.0  2020-04-30         277486509
# 1             2.0         160.00         160.0  2020-05-05         277486509
# 2             3.0          80.00          80.0  2020-05-08         815939440
# 3             3.0          80.00          80.0  2020-05-08         815939440
# 4             3.0          80.00          80.0  2020-05-08         815939440
# ...           ...            ...           ...         ...               ...
# 969730     3000.0        2135.70           NaN        None         265655619
# 969731     3000.0        2135.70           NaN        None         265655619
# 969732     3000.0        2135.70           NaN        None         265655619
# 969733     3607.0         396.57           NaN        None         615053396
# 969734     3607.0         396.57           NaN        None         615053396
#
#          status  price_zone_code u_ndis_number       u_disabilities u_gender  \
# 0       managed  ACT_NSW_QLD_VIC     277486509                          Male
# 1       managed  ACT_NSW_QLD_VIC     277486509                          Male
# 2       managed  ACT_NSW_QLD_VIC     815939440                        Female
# 3       managed  ACT_NSW_QLD_VIC     815939440                        Female
# 4       managed  ACT_NSW_QLD_VIC     815939440                        Female
# ...         ...              ...           ...                  ...      ...
# 969730  managed  ACT_NSW_QLD_VIC     265655619                         Other
# 969731  managed  ACT_NSW_QLD_VIC     265655619                         Other
# 969732  managed  ACT_NSW_QLD_VIC     265655619                         Other
# 969733  managed  ACT_NSW_QLD_VIC     615053396  Parkinson's disease     Male
# 969734  managed  ACT_NSW_QLD_VIC     615053396  Parkinson's disease     Male
#
#        u_date_of_birth        SA1      SA2      SA3    SA4  \
# 0           1958-04-12  3110117.0  31101.0  30404.0  304.0
# 1           1958-04-12  3110117.0  31101.0  30404.0  304.0
# 2           1937-10-25  3130913.0  31309.0  31102.0  311.0
# 3           1937-10-25  3130913.0  31309.0  31102.0  311.0
# 4           1937-10-25  3130913.0  31309.0  31102.0  311.0
# ...                ...        ...      ...      ...    ...
# 969730      1981-04-07        0.0      0.0      0.0    0.0
# 969731      1981-04-07        0.0      0.0      0.0    0.0
# 969732      1981-04-07        0.0      0.0      0.0    0.0
# 969733      1943-08-12  3136525.0  31365.0  31302.0  313.0
# 969734      1943-08-12  3136525.0  31365.0  31302.0  313.0
#
#                                        registration_group  \
# 0                                    Therapeutic Supports
# 1                                    Therapeutic Supports
# 2                                    Therapeutic Supports
# 3                                    Therapeutic Supports
# 4                                    Therapeutic Supports
# ...                                                   ...
# 969730  Participation In Community, Social And Civic A...
# 969731  Participation In Community, Social And Civic A...
# 969732  Participation In Community, Social And Civic A...
# 969733  Participation In Community, Social And Civic A...
# 969734  Participation In Community, Social And Civic A...
#
#         provider_account_id provider_abn
# 0                     157.0  13448919450
# 1                     157.0  13448919450
# 2                    1877.0    454964437
# 3                    1877.0    454964437
# 4                    1877.0    454964437
# ...                     ...          ...
# 969730              16368.0  81648529524
# 969731              16368.0  81648529524
# 969732              16368.0  81648529524
# 969733              15369.0  36351459618
# 969734              15369.0  36351459618
#
# [969735 rows x 23 columns]

# %%
df.columns.tolist()
# Out:
# ['claim_id',
#  'invoice_id',
#  'state',
#  'risk_level',
#  'start_date',
#  'member_id',
#  'invoice_total',
#  'funded_total',
#  'funded_date',
#  'membership_number',
#  'status',
#  'price_zone_code',
#  'u_ndis_number',
#  'u_disabilities',
#  'u_gender',
#  'u_date_of_birth',
#  'SA1',
#  'SA2',
#  'SA3',
#  'SA4',
#  'registration_group',
#  'provider_account_id',
#  'provider_abn']

# %%
df['u_disabilities'].value_counts()
# Out:
#                                                                                                                                                                                                                                                                    665985
# Intellectual disability                                                                                                                                                                                                                                             15011
# Down syndrome                                                                                                                                                                                                                                                       13047
# Cerebral palsy                                                                                                                                                                                                                                                      12261
# Acquired Brain Injury                                                                                                                                                                                                                                                7816
#                                                                                                                                                                                                                                                                     ...
# Mental health, Schizophrenia                                                                                                                                                                                                                                            2
# Global development delay                                                                                                                                                                                                                                                2
# Schizophrenia, Bipolar disorder                                                                                                                                                                                                                                         2
# Deaf in my right ear.                                                                                                                                                                                                                                                   1
# Anxiety, Mental Stress, "StP" = Supposed Diagnosis of Schizophre, Psychosis , Akathisia, Insistence on wanting to hear, as it was, As I said that I am being spiritually at, False Accussation of Paranoia, Mundane, same thing of nothing each and , Entrapmen         1
# Name: u_disabilities, Length: 569, dtype: int64

# %%
### Visualise the u_disabilities
df['u_disabilities'].value_counts(sort=True).nlargest(15)
#df['u_disabilities'].value_counts(sort=True).nlargest(15).sum()
# Out:
#                            665985
# Intellectual disability     15011
# Down syndrome               13047
# Cerebral palsy              12261
# Acquired Brain Injury        7816
# Vision Impaired              7571
# Multiple Sclerosis           7544
# Schizophrenia                5085
# Intellectual impairment      4363
# Brain Injury                 4051
# ADHD                         3791
# Spina bifida                 3485
# spinal cord injury           3081
# Stroke (cerebellar)          3029
# Mental health                2456
# Name: u_disabilities, dtype: int64

# %%
df['u_disabilities'].value_counts(sort=True).nlargest(15).plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### signifcant number of un_known disabilities type of 665985 - need to work out how to fill this

# %%
bool_series = pd.isnull(df['u_disabilities']) 
    
# filtering data 
# displaying data only with u_disabilities = NaN 

df[bool_series].head(1000)
# Out:
#       claim_id  invoice_id state risk_level start_date  member_id  \
# 28         NaN         NaN   NaN        NaN        NaN        NaN
# 29         NaN         NaN   NaN        NaN        NaN        NaN
# 30         NaN         NaN   NaN        NaN        NaN        NaN
# 31         NaN         NaN   NaN        NaN        NaN        NaN
# 32         NaN         NaN   NaN        NaN        NaN        NaN
# ...        ...         ...   ...        ...        ...        ...
# 3953       NaN         NaN   NaN        NaN        NaN        NaN
# 3959       NaN         NaN   NaN        NaN        NaN        NaN
# 3960       NaN         NaN   NaN        NaN        NaN        NaN
# 3976       NaN         NaN   NaN        NaN        NaN        NaN
# 3978       NaN         NaN   NaN        NaN        NaN        NaN
#
#       invoice_total  funded_total funded_date membership_number status  \
# 28              NaN           NaN         NaN               NaN    NaN
# 29              NaN           NaN         NaN               NaN    NaN
# 30              NaN           NaN         NaN               NaN    NaN
# 31              NaN           NaN         NaN               NaN    NaN
# 32              NaN           NaN         NaN               NaN    NaN
# ...             ...           ...         ...               ...    ...
# 3953            NaN           NaN         NaN               NaN    NaN
# 3959            NaN           NaN         NaN               NaN    NaN
# 3960            NaN           NaN         NaN               NaN    NaN
# 3976            NaN           NaN         NaN               NaN    NaN
# 3978            NaN           NaN         NaN               NaN    NaN
#
#      price_zone_code u_ndis_number u_disabilities u_gender u_date_of_birth  \
# 28               NaN           NaN            NaN      NaN             NaN
# 29               NaN           NaN            NaN      NaN             NaN
# 30               NaN           NaN            NaN      NaN             NaN
# 31               NaN           NaN            NaN      NaN             NaN
# 32               NaN           NaN            NaN      NaN             NaN
# ...              ...           ...            ...      ...             ...
# 3953             NaN           NaN            NaN      NaN             NaN
# 3959             NaN           NaN            NaN      NaN             NaN
# 3960             NaN           NaN            NaN      NaN             NaN
# 3976             NaN           NaN            NaN      NaN             NaN
# 3978             NaN           NaN            NaN      NaN             NaN
#
#       SA1  SA2  SA3  SA4 registration_group  provider_account_id provider_abn
# 28    NaN  NaN  NaN  NaN                NaN                  NaN          NaN
# 29    NaN  NaN  NaN  NaN                NaN                  NaN          NaN
# 30    NaN  NaN  NaN  NaN                NaN                  NaN          NaN
# 31    NaN  NaN  NaN  NaN                NaN                  NaN          NaN
# 32    NaN  NaN  NaN  NaN                NaN                  NaN          NaN
# ...   ...  ...  ...  ...                ...                  ...          ...
# 3953  NaN  NaN  NaN  NaN                NaN                  NaN          NaN
# 3959  NaN  NaN  NaN  NaN                NaN                  NaN          NaN
# 3960  NaN  NaN  NaN  NaN                NaN                  NaN          NaN
# 3976  NaN  NaN  NaN  NaN                NaN                  NaN          NaN
# 3978  NaN  NaN  NaN  NaN                NaN                  NaN          NaN
#
# [1000 rows x 23 columns]

# %%
df['u_disabilities'].value_counts(sort=True).nsmallest(15)
# Out:
# Deaf in my right ear.                                                                                                                                                                                                                                              1
# Anxiety, Mental Stress, "StP" = Supposed Diagnosis of Schizophre, Psychosis , Akathisia, Insistence on wanting to hear, as it was, As I said that I am being spiritually at, False Accussation of Paranoia, Mundane, same thing of nothing each and , Entrapmen    1
# Intellectual disability, Oppositional defiance disorder , ADHD                                                                                                                                                                                                     2
# Mental health, Schizophrenia                                                                                                                                                                                                                                       2
# Global development delay                                                                                                                                                                                                                                           2
# Schizophrenia, Bipolar disorder                                                                                                                                                                                                                                    2
# Deafblindness                                                                                                                                                                                                                                                      3
# Charcot Marie tooth syndrome type 2 c an                                                                                                                                                                                                                           3
# Hearing, Intellectual disability                                                                                                                                                                                                                                   3
# ADHD, Chromosome 8p duplication                                                                                                                                                                                                                                    4
# Behavioural problems , ADHD                                                                                                                                                                                                                                        4
# Attention deficit hyperactivity disorder, Fetal alcohol syndrome, Anxiety                                                                                                                                                                                          5
# Epidermolysis Bullosa                                                                                                                                                                                                                                              5
# Asperger syndrome, anxiety                                                                                                                                                                                                                                         5
# Muscle wasting condition with little or                                                                                                                                                                                                                            6
# Name: u_disabilities, dtype: int64

# %% [markdown]
# ### We should check the dataframe again, it seems like we lost numerous rows when we merged

# %%
### checking all NAN rows and try dropping if the row is all NANs:

df.dropna(how = 'all')
# Out:
#          claim_id  invoice_id                state risk_level  start_date  \
# 0             1.0         1.0                 PAID         NO  2020-04-30
# 1             2.0         2.0                 PAID         NO  2020-05-01
# 2             3.0         3.0                 PAID         NO  2020-04-23
# 3             4.0         4.0                 PAID         NO  2020-04-30
# 4             5.0         5.0                 PAID         NO  2020-05-07
# ...           ...         ...                  ...        ...         ...
# 969730  1006095.0    539315.0  OPERATOR_AUTHORIZED         NO  2021-04-08
# 969731  1006096.0    539315.0  OPERATOR_AUTHORIZED         NO  2021-04-10
# 969732  1006097.0    539315.0  OPERATOR_AUTHORIZED         NO  2021-04-11
# 969733  1006098.0    539316.0  OPERATOR_AUTHORIZED         NO  2021-04-15
# 969734  1006099.0    539316.0  OPERATOR_AUTHORIZED         NO  2021-04-15
#
#         member_id  invoice_total  funded_total funded_date membership_number  \
# 0             2.0         160.00         160.0  2020-04-30         277486509
# 1             2.0         160.00         160.0  2020-05-05         277486509
# 2             3.0          80.00          80.0  2020-05-08         815939440
# 3             3.0          80.00          80.0  2020-05-08         815939440
# 4             3.0          80.00          80.0  2020-05-08         815939440
# ...           ...            ...           ...         ...               ...
# 969730     3000.0        2135.70           NaN        None         265655619
# 969731     3000.0        2135.70           NaN        None         265655619
# 969732     3000.0        2135.70           NaN        None         265655619
# 969733     3607.0         396.57           NaN        None         615053396
# 969734     3607.0         396.57           NaN        None         615053396
#
#          status  price_zone_code u_ndis_number       u_disabilities u_gender  \
# 0       managed  ACT_NSW_QLD_VIC     277486509                          Male
# 1       managed  ACT_NSW_QLD_VIC     277486509                          Male
# 2       managed  ACT_NSW_QLD_VIC     815939440                        Female
# 3       managed  ACT_NSW_QLD_VIC     815939440                        Female
# 4       managed  ACT_NSW_QLD_VIC     815939440                        Female
# ...         ...              ...           ...                  ...      ...
# 969730  managed  ACT_NSW_QLD_VIC     265655619                         Other
# 969731  managed  ACT_NSW_QLD_VIC     265655619                         Other
# 969732  managed  ACT_NSW_QLD_VIC     265655619                         Other
# 969733  managed  ACT_NSW_QLD_VIC     615053396  Parkinson's disease     Male
# 969734  managed  ACT_NSW_QLD_VIC     615053396  Parkinson's disease     Male
#
#        u_date_of_birth        SA1      SA2      SA3    SA4  \
# 0           1958-04-12  3110117.0  31101.0  30404.0  304.0
# 1           1958-04-12  3110117.0  31101.0  30404.0  304.0
# 2           1937-10-25  3130913.0  31309.0  31102.0  311.0
# 3           1937-10-25  3130913.0  31309.0  31102.0  311.0
# 4           1937-10-25  3130913.0  31309.0  31102.0  311.0
# ...                ...        ...      ...      ...    ...
# 969730      1981-04-07        0.0      0.0      0.0    0.0
# 969731      1981-04-07        0.0      0.0      0.0    0.0
# 969732      1981-04-07        0.0      0.0      0.0    0.0
# 969733      1943-08-12  3136525.0  31365.0  31302.0  313.0
# 969734      1943-08-12  3136525.0  31365.0  31302.0  313.0
#
#                                        registration_group  \
# 0                                    Therapeutic Supports
# 1                                    Therapeutic Supports
# 2                                    Therapeutic Supports
# 3                                    Therapeutic Supports
# 4                                    Therapeutic Supports
# ...                                                   ...
# 969730  Participation In Community, Social And Civic A...
# 969731  Participation In Community, Social And Civic A...
# 969732  Participation In Community, Social And Civic A...
# 969733  Participation In Community, Social And Civic A...
# 969734  Participation In Community, Social And Civic A...
#
#         provider_account_id provider_abn
# 0                     157.0  13448919450
# 1                     157.0  13448919450
# 2                    1877.0    454964437
# 3                    1877.0    454964437
# 4                    1877.0    454964437
# ...                     ...          ...
# 969730              16368.0  81648529524
# 969731              16368.0  81648529524
# 969732              16368.0  81648529524
# 969733              15369.0  36351459618
# 969734              15369.0  36351459618
#
# [903860 rows x 23 columns]

# %% [markdown]
# ### 903860 rows left over 968874 in original df which is not too bad to drop

# %%
df['u_gender'].value_counts()
# Out:
# Male      390485
# Female    348237
#           163236
# Other       1902
# Name: u_gender, dtype: int64

# %%
df['u_gender'].value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='u_gender'>

# %%
# Approximation of Service Provider's Region based on invoices

# Minimal customer and invoice information
df_invoice_min = pd.read_sql("SELECT i.id as invoice_id, i.member_id, i.provider_account_id FROM HH_invoice i;", con=conn)
df_customer_min = pd.read_sql("select m.id as member_id, r.SA1, r.SA2, r.SA3, r.SA4 from SNOW_csm_consumer_user s left join  HH_member m  on s.u_ndis_number = m.membership_number left join libe_leapinprod_memberregion r on r.MemberId = s.u_leapin_id where s.u_stage = 'li_managed' and s.u_ndis_number is not null", con=conn)
df_invoice_customer_min = pd.merge(df_invoice_min, df_customer_min, on="member_id", how="left")

cleaned_df = df_invoice_customer_min

count = 1

# Eliminate rows with null SA1-4 values
while count <= 4:

    rowName = "SA" + str(count)

    # Remove blank SA1 - SA4 values
    blankIndices = df_invoice_customer_min[df_invoice_customer_min[rowName] == 0.0].index

    cleaned_df = df_invoice_customer_min.drop(axis=0, labels=blankIndices)

    count += 1

# Eliminate null rows
cleaned_df = cleaned_df.dropna()

cleaned_df.info()

cleaned_df.to_csv("test_clean.csv")

df_sa1 = pd.read_csv("./../TableDump/SA1_2016.csv")
df_sa2 = pd.read_csv("./../TableDump/SA2_2016.csv")
df_sa3 = pd.read_csv("./../TableDump/SA3_2016.csv")
df_sa4 = pd.read_csv("./../TableDump/SA4_2016.csv")

df_invoice_provider_region = pd.merge(cleaned_df, )


df_sa1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 307216 entries, 0 to 518375
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   invoice_id           307216 non-null  int64
#  1   member_id            307216 non-null  int64
#  2   provider_account_id  307216 non-null  int64
#  3   SA1                  307216 non-null  float64
#  4   SA2                  307216 non-null  float64
#  5   SA3                  307216 non-null  float64
#  6   SA4                  307216 non-null  float64
# dtypes: float64(4), int64(3)
# memory usage: 18.8 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57523 entries, 0 to 57522
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   SA1_MAINCODE_2016    57523 non-null  int64
#  1   SA1_7DIGITCODE_2016  57523 non-null  int64
#  2   SA2_MAINCODE_2016    57523 non-null  int64
#  3   SA2_5DIGITCODE_2016  57523 non-null  int64
#  4   SA2_NAME_2016        57523 non-null  object
#  5   SA3_CODE_2016        57523 non-null  int64
#  6   SA3_NAME_2016        57523 non-null  object
#  7   SA4_CODE_2016        57523 non-null  int64
#  8   SA4_NAME_2016        57523 non-null  object
#  9   GCCSA_CODE_2016      57523 non-null  object
#  10  GCCSA_NAME_2016      57523 non-null  object
#  11  STATE_CODE_2016      57523 non-null  int64
#  12  STATE_NAME_2016      57523 non-null  object
#  13  AREA_ALBERS_SQKM     57523 non-null  float64
# dtypes: float64(1), int64(7), object(6)
# memory usage: 6.1+ MB
